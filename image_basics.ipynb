# %% [markdown]
# # Image Creation

# %%
# Creating a (6, 8) grayscale image with a white pixel at (2, 3)
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
im = np.zeros((6,8), dtype=np.uint8)
im[2,3] = 255
fig, ax = plt.subplots(1, 1, figsize=(6, 8))
ax.imshow(im, cmap='gray', vmin=0, vmax=255)
ax.xaxis.set_ticks_position('top')
plt.show()

# %%
# Creating a (6, 8) color image with a pink pixel at (2, 3)
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
im = np.zeros((6,8,3), dtype=np.uint8)
im[2,3] = (255, 190, 203)
fig, ax = plt.subplots(1, 1, figsize=(6, 8))
ax.imshow(im)
ax.xaxis.set_ticks_position('top')
plt.show()

# %%
# Opening an Image and Displaying Using Matplotlib.
import cv2 as cv
import matplotlib.pyplot as plt
im = cv.imread('images\jeniffer.jpg')
fig, ax = plt.subplots(1, 1, figsize=(6, 8))
ax.imshow(cv.cvtColor(im, cv.COLOR_BGR2RGB))
ax.xaxis.set_ticks_position('top')
plt.show()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\j'
# <>:4: SyntaxWarning: invalid escape sequence '\j'
# C:\Users\nadil\AppData\Local\Temp\ipykernel_25076\2554115449.py:4: SyntaxWarning: invalid escape sequence '\j'
#   im = cv.imread('images\jeniffer.jpg')

# %%
# Opening an Image and Displaying Using OpenCV.
import cv2 as cv
im = cv.imread('images/emma.jpg')
cv.namedWindow('Image', cv.WINDOW_AUTOSIZE) 
cv.imshow('Image', im)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
# Opening an Image and Displaying Properties.
import cv2 as cv
import matplotlib.pyplot as plt
im = cv.imread('images/hugh.jpg')
fig, ax = plt.subplots(1, 1, figsize=(6, 8))
ax.imshow(cv.cvtColor(im, cv.COLOR_BGR2RGB))
ax.xaxis.set_ticks_position('top')
plt.show()
print('Image Shape:', im.shape)
print('Image Data Type:', im.dtype)
print('Image Size:', im.size)
# Out:
# Image Shape: (490, 980, 3)
# Image Data Type: uint8
# Image Size: 1440600

# %%
# Open keira_gray.jpg and increase its brightness.
from turtle import title
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
im1 = cv.imread('images/keira_gray.jpg', cv.IMREAD_GRAYSCALE)
im2 = cv.add(im1, 100)
fig, ax = plt.subplots(1, 2, figsize=(6, 8))
ax[0].imshow(im1, cmap='gray', vmin=0, vmax=255)
ax[0].set_title('Original Image')
ax[1].imshow(im2, cmap='gray', vmin=0, vmax=255)
ax[1].set_title('Brightness Increased')
for a in ax:
    a.axis('off')
plt.show()
